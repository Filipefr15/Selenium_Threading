# %%
import scrapy
import time
from scrapy_selenium import SeleniumRequest
from scrapy.selector import Selector
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from shutil import which
from openpyxl import load_workbook

wb = load_workbook('BD_CADASTRO_NUMERADO_AGO_TESTE.xlsx')
ws, ws2 = wb['Fundos'], wb['Fundos_Cota']
lista_cnpj = []

for row in ws.iter_rows(values_only=True):
    cnpj = row[1]
    lista_cnpj.append(cnpj)

for row in ws2.iter_rows(values_only=True):
    cnpj = row[1] 
    lista_cnpj.append(cnpj)

lista_cnpj_override = "01.608.573/0001-65"

# webdriver.ChromeOptions é usado para definir a preferência para o browser do Chrome
options = webdriver.ChromeOptions()

#faz com que nao abra a página.
options.add_argument("--headless=new")

driver = webdriver.Chrome(executable_path=which('chromedriver'), options=options)

url='https://cvmweb.cvm.gov.br/swb/default.asp?sg_sistema=fundosreg'

driver.get(url)

#pesquisa e troca para o frame correto sem precisar declarar uma variável nova no processo
WebDriverWait(driver, 10).until(
EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
)

search_input = WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//input[@id='txtCNPJNome']"))
)
search_input.clear()
#search_input.send_keys(lista_cnpj[0])
search_input.send_keys(lista_cnpj_override)
search_input.send_keys(Keys.ENTER)

find_name_to_store = WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//a[@id='ddlFundos__ctl0_lnkbtn1']"))
)
stored_name = find_name_to_store.text
find_name_to_store.click()

driver.switch_to.default_content()

#pesquisa e troca para o frame correto sem precisar declarar uma variável nova no processo
WebDriverWait(driver, 10).until(
    EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
)

dados_diarios = WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//a[@id='Hyperlink2']"))
)
dados_diarios.click()

driver.switch_to.default_content()

#pop-up com mensagem irrelevante aparece e precisa ser fechado.
try:
    alert = WebDriverWait(driver, 3).until(EC.alert_is_present())
    alert.accept()
except:
    pass

WebDriverWait(driver, 10).until(
    EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
)

dropdown_data_pesquisa = Select(WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
))

dados_diarios_list = []
for i, _ in enumerate(dropdown_data_pesquisa.options):
    driver.switch_to.default_content()

    WebDriverWait(driver, 10).until(
    EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
    )

    dropdown_data_pesquisa = Select(WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
    ))
    dropdown_data_pesquisa.select_by_index(i)

    name_selected_dropdown = Select(WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
    ))
    name_selected_dropdown = name_selected_dropdown.first_selected_option.get_attribute("value")
    
    linhas_tabela = WebDriverWait(driver, 10).until(
        EC.presence_of_all_elements_located((By.XPATH, "//table[@id='dgDocDiario']//tr[position()>1]"))
    )
    linhas_validas = [linha for linha in linhas_tabela if linha.find_element(By.XPATH, "td[2]").text.strip()] 
    
    if linhas_validas:
        ultima_linha = linhas_validas[-1]
        dados = ultima_linha.find_elements(By.XPATH, "td")
        dados_diarios = {
            "Mês": name_selected_dropdown,
            "Dia": dados[0].text.strip(),
            "Quota": dados[1].text.strip(),
            #"Captação no Dia": dados[2].text.strip(),
            #"Resgate no Dia": dados[3].text.strip(),
            "Patrimônio Líquido": dados[4].text.strip(),
            #"Total da Carteira": dados[5].text.strip(),
            "Número de Cotistas": dados[6].text.strip(),
            #"Data da Próxima Informação do PL": dados[7].text.strip(),
        }
        dados_diarios_list.append(dados_diarios)
#dropdown.select_by_visible_text('02/2025')
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# Cell In[72], line 102
#      97 dropdown_data_pesquisa = Select(WebDriverWait(driver, 10).until(
#      98     EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
#      99 ))
#     100 dropdown_data_pesquisa.select_by_index(i)
# --> 102 name_selected_dropdown = Select(WebDriverWait(driver, 10).until(
#     103     EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
#     104 ))
#     105 name_selected_dropdown = name_selected_dropdown.first_selected_option.get_attribute("value")
#     107 linhas_tabela = WebDriverWait(driver, 10).until(
#     108     EC.presence_of_all_elements_located((By.XPATH, "//table[@id='dgDocDiario']//tr[position()>1]"))
#     109 )
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\wait.py:71, in WebDriverWait.until(self, method, message)
#      69 while True:
#      70     try:
# ---> 71         value = method(self._driver)
#      72         if value:
#      73             return value
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\expected_conditions.py:64, in presence_of_element_located.__call__(self, driver)
#      63 def __call__(self, driver):
# ---> 64     return _find_element(driver, self.locator)
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\expected_conditions.py:415, in _find_element(driver, by)
#     413     raise e
#     414 except WebDriverException as e:
# --> 415     raise e
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\expected_conditions.py:411, in _find_element(driver, by)
#     408 """Looks up an element. Logs and re-raises ``WebDriverException``
#     409 if thrown."""
#     410 try:
# --> 411     return driver.find_element(*by)
#     412 except NoSuchElementException as e:
#     413     raise e
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:241, in ErrorHandler.check_response(self, response)
#     239     elif 'alert' in value:
#     240         alert_text = value['alert'].get('text')
# --> 241     raise exception_class(message, screen, stacktrace, alert_text)
#     242 raise exception_class(message, screen, stacktrace)
#
# UnexpectedAlertPresentException: Alert Text: Estes documentos são referentes ao participante anterior a adaptação a Instrução CVM nº 409: BB TOP RENDA FIXA CURTO PRAZO FUNDO DE INVESTIMENTO.
# Message: unexpected alert open: {Alert text : Estes documentos são referentes ao participante anterior a adaptação a Instrução CVM nº 409: BB TOP RENDA FIXA CURTO PRAZO FUNDO DE INVESTIMENTO.}
#   (Session info: chrome=133.0.6943.98)

# %%
dados_diarios_list
# Out:
# [{'Mês': '02/2025',
#   'Dia': '13',
#   'Quota': '22,253360922',
#   'Patrimônio Líquido': '78.614.539.897,52',
#   'Número de Cotistas': '45'},
#  {'Mês': '01/2025',
#   'Dia': '31',
#   'Quota': '22,157352602',
#   'Patrimônio Líquido': '71.449.766.504,84',
#   'Número de Cotistas': '45'},
#  {'Mês': '12/2024',
#   'Dia': '31',
#   'Quota': '21,940251028',
#   'Patrimônio Líquido': '67.427.765.365,53',
#   'Número de Cotistas': '43'},
#   'Quota': '3,93548711',
#   'Patrimônio Líquido': '14.169.749.187,36',
#   'Número de Cotistas': '10'},
#  {'Mês': '06/2006',
#   'Dia': '30',
#   'Quota': '3,890000142',
#   'Patrimônio Líquido': '14.083.519.663,97',
#   'Número de Cotistas': '10'},
#  {'Mês': '05/2006',
#   'Dia': '31',
#   'Quota': '3,844581722',
#   'Patrimônio Líquido': '14.583.502.306,95',
#   'Número de Cotistas': '13'},
#  {'Mês': '04/2006',
#   'Dia': '28',
#   'Quota': '3,796072255',
#   'Patrimônio Líquido': '14.291.786.669,64',
#   'Número de Cotistas': '13'},
#  {'Mês': '03/2006',
#   'Dia': '31',
#   'Quota': '3,755638709',
#   'Patrimônio Líquido': '13.867.568.403,51',
#   'Número de Cotistas': '13'},
#  {'Mês': '02/2006',
#   'Dia': '24',
#   'Quota': '3,703078922',
#   'Patrimônio Líquido': '14.229.146.976,05',
#   'Número de Cotistas': '13'},
#  {'Mês': '01/2006',
#   'Dia': '31',
#   'Quota': '3,66121548',
#   'Patrimônio Líquido': '13.933.931.983,47',
#   'Número de Cotistas': '13'},
#  {'Mês': '12/2005',
#   'Dia': '30',
#   'Quota': '3,609566561',
#   'Patrimônio Líquido': '10.252.491.000,33',
#   'Número de Cotistas': '14'},
#  {'Mês': '11/2005',
#   'Dia': '30',
#   'Quota': '3,557104882',
#   'Patrimônio Líquido': '11.532.505.565,14',
#   'Número de Cotistas': '15'},
#  {'Mês': '10/2005',
#   'Dia': '31',
#   'Quota': '3,508608161',
#   'Patrimônio Líquido': '10.936.878.821,11',
#   'Número de Cotistas': '14'},
#  {'Mês': '09/2005',
#   'Dia': '30',
#   'Quota': '3,459916727',
#   'Patrimônio Líquido': '10.875.205.406,22',
#   'Número de Cotistas': '14'},
#  {'Mês': '08/2005',
#   'Dia': '31',
#   'Quota': '3,408562874',
#   'Patrimônio Líquido': '11.528.811.651,63',
#   'Número de Cotistas': '14'},
#  {'Mês': '07/2005',
#   'Dia': '29',
#   'Quota': '3,353002391',
#   'Patrimônio Líquido': '11.465.962.557,78',
#   'Número de Cotistas': '14'},
#  {'Mês': '06/2005',
#   'Dia': '30',
#   'Quota': '3,303063341',
#   'Patrimônio Líquido': '11.585.184.412,18',
#   'Número de Cotistas': '14'},
#  {'Mês': '05/2005',
#   'Dia': '31',
#   'Quota': '3,251517847',
#   'Patrimônio Líquido': '11.325.616.874,92',
#   'Número de Cotistas': '13'},
#  {'Mês': '04/2005',
#   'Dia': '29',
#   'Quota': '3,203476561',
#   'Patrimônio Líquido': '10.514.351.469,29',
#   'Número de Cotistas': '13'},
#  {'Mês': '03/2005',
#   'Dia': '31',
#   'Quota': '3,159040701',
#   'Patrimônio Líquido': '9.899.859.687,84',
#   'Número de Cotistas': '13'}]

# %%
driver.switch_to.default_content()

WebDriverWait(driver, 10).until(
EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
)

dropdown_data_pesquisa = Select(WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
))
dropdown_data_pesquisa.select_by_index(i)

# %%
a = dropdown_data_pesquisa.select_by_index(i)

# %%
dropdown_data_pesquisa.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 a.text()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
driver.switch_to.default_content()

WebDriverWait(driver, 10).until(
    EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
)

dropdown_data_pesquisa = Select(WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
))

dropdown_data_pesquisa.select_by_value("12/2024")

# %%
driver.switch_to.default_content()

WebDriverWait(driver, 10).until(
    EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
)

search_selections = Select(WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
))

dates = search_selections.options

# %%
dates = search_selections.options
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 dates = search_selections.options
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\select.py:47, in Select.options(self)
#      44 @property
#      45 def options(self):
#      46     """Returns a list of all options belonging to this select tag"""
# ---> 47     return self._el.find_elements(By.TAG_NAME, 'option')
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:684, in WebElement.find_elements(self, by, value)
#     681         by = By.CSS_SELECTOR
#     682         value = '[name="%s"]' % value
# --> 684 return self._execute(Command.FIND_CHILD_ELEMENTS,
#     685                      {"using": by, "value": value})['value']
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:633, in WebElement._execute(self, command, params)
#     631     params = {}
#     632 params['id'] = self._id
# --> 633 return self._parent.execute(command, params)
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=133.0.6943.98)

# %%
for i, date in enumerate(dates):
    driver.switch_to.default_content()

    WebDriverWait(driver, 10).until(
        EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
    )

    dropdown_data_pesquisa = Select(WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
    ))

    dropdown_data_pesquisa.select_by_index(i)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[38], line 4
#       1 for i, date in enumerate(dates):
#       2     driver.switch_to.default_content()
# ----> 4     WebDriverWait(driver, 10).until(
#       5         EC.frame_to_be_available_and_switch_to_it((By.XPATH, "//frame[@name='Main']"))
#       6     )
#       8     dropdown_data_pesquisa = Select(WebDriverWait(driver, 10).until(
#       9         EC.presence_of_element_located((By.XPATH, "//select[@name='ddComptc']"))
#      10     ))
#      12     dropdown_data_pesquisa.select_by_index(i)
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\wait.py:71, in WebDriverWait.until(self, method, message)
#      69 while True:
#      70     try:
# ---> 71         value = method(self._driver)
#      72         if value:
#      73             return value
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\expected_conditions.py:247, in frame_to_be_available_and_switch_to_it.__call__(self, driver)
#     245 try:
#     246     if isinstance(self.frame_locator, tuple):
# --> 247         driver.switch_to.frame(_find_element(driver,
#     248                                              self.frame_locator))
#     249     else:
#     250         driver.switch_to.frame(self.frame_locator)
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\expected_conditions.py:415, in _find_element(driver, by)
#     413     raise e
#     414 except WebDriverException as e:
# --> 415     raise e
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\expected_conditions.py:411, in _find_element(driver, by)
#     408 """Looks up an element. Logs and re-raises ``WebDriverException``
#     409 if thrown."""
#     410 try:
# --> 411     return driver.find_element(*by)
#     412 except NoSuchElementException as e:
#     413     raise e
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File c:\Users\frodrigues\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=133.0.6943.98)
